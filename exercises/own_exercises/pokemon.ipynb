# %%
import pandas as pd

df = pd.read_csv("../data/pokemon.csv")

# %%
df.head(10)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 9  ['Shield Dust', 'Run Away']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
df.shape
# Out:
# (801, 41)

# %%
top_10_strongest = (df[["name","attack"]]).sort_values(by = "attack",ascending = False).head(10)
top_10_strongest
# Out:
#           name  attack
# 213  Heracross     185
# 797    Kartana     181
# 383   Rayquaza     180
# 382    Groudon     180
# 444   Garchomp     170
# 353    Banette     165
# 474    Gallade     165
# 408  Rampardos     165
# 247  Tyranitar     164
# 288    Slaking     160

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.plot(top_10_strongest['name'],top_10_strongest['attack'],color = 'red',linewidth=2)
plt.scatter(top_10_strongest['name'],top_10_strongest['attack'])

plt.title("Top 10 strongest Pokemons",loc = 'left',pad= 15,fontsize = 15,color = 'gray')
plt.xlabel("Pokemon name",labelpad = 15,fontsize =15,color = 'gray')
plt.ylabel("Attack damage",labelpad= 15,fontsize = 15,color = 'gray')

ax = plt.gca()
ax.spines[['right','top']].set_visible(False)

plt.tick_params(axis="both",length = 0)


plt.tight_layout()
plt.savefig("../plots/strongest_pokemons.png",dpi = 300)

# %%
top_10_strongest['type1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nirre\OneDrive\Skrivbord\github_repos\data_visualization\data_visualization\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ...
