# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.annotate('Här ska pilen börja', xy=(0.4,0.6), xytext=(0.33, 0.8),arrowprops=dict(arrowstyle='->',connectionstyle ='arc,rad = -0.5'))
ax.annotate('Här ska pilen sluta', xy=(0.4,0.6), xytext=(0.4, 0.55))
# Out:
# Text(0.4, 0.55, 'Här ska pilen sluta')
