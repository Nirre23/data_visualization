# %%
import pandas as pd     
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
types = df['type'].value_counts()

# %%
fig ,ax = plt.subplots(figsize=(3, 3))
ax.bar(types.index, types.values, color = 'steelblue',width=.2)
ax.set_title('Netflix Titles by Type', fontsize=14)
ax.set_xlabel('Type', fontsize=12)
ax.set_ylabel('Count', fontsize=12)
ax.legend(['Movies', 'TV Shows'], loc='upper right')
ax.
# Out:
#   Cell In[29], line 7
#     ax.
#        ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# Skapa en figur med 2 axlar (subplots)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot på första axeln (ax1)
ax1.plot([1, 2, 3], [4, 5, 6])
ax1.set_title("Plot 1")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")


# Plot på andra axeln (ax2)
ax2.plot([1, 2, 3], [6, 5, 4])
ax2.set_title("Plot 2")
ax2.set_xlabel("X-axis")
ax2.set_ylabel("Y-axis")

# Visa hela figuren
plt.tight_layout()  # För att justera layouten så att plotten inte överlappar
plt.show()
