# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns   

df = pd.read_excel('../data/happiness.xlsx')

# %%
df
# Out:
#          Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0             Finland        7.7407      7.814808      7.666591
# 1             Denmark        7.5827      7.665297      7.500103
# 2             Iceland        7.5251      7.617527      7.432673
# 3              Sweden        7.3441      7.421563      7.266637
# 4              Israel        7.3411      7.405165      7.277036
# ..                ...           ...           ...           ...
# 138  Congo (Kinshasa)        3.2954      3.462328      3.128472
# 139      Sierra Leone        3.2452      3.366252      3.124148
# 140           Lesotho        3.1862      3.468785      2.903615
# 141           Lebanon        2.7065      2.796744      2.616256
# 142       Afghanistan        1.7210      1.775271      1.666728
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 0                            1.844054                      1.572367
# ...

# %%
print(df.describe())
# Out:
#        Ladder score  upperwhisker  lowerwhisker  \
# count    143.000000    143.000000    143.000000
# mean       5.527572      5.641158      5.413986
# std        1.170690      1.154980      1.187131
# min        1.721000      1.775271      1.666728
# 25%        4.725700      4.845570      4.605831
# 50%        5.785300      5.894504      5.674096
# 75%        6.415850      6.507774      6.319137
# max        7.740700      7.814808      7.666591
#
#        Explained by: Log GDP per capita  Explained by: Social support  \
# count                        140.000000                    140.000000
# mean                           1.378779                      1.134323
# std                            0.425085                      0.333309
# min                            0.000000                      0.000000
# 25%                            1.077373                      0.921409
# 50%                            1.431220                      1.237206
# ...

# %%
df.columns
# Out:
# Index(['Country name', 'Ladder score', 'upperwhisker', 'lowerwhisker',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
sns.histplot(df['Ladder score'])

plt.show()

# %%
sns.boxplot(x=df['Ladder score'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x=df['Ladder score'], y=df['Country name'])
plt.show()

# %%
df.columns
# Out:
# Index(['Country name', 'Ladder score', 'upperwhisker', 'lowerwhisker',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df.columns = ['Country', 'Ladder_Score', 'Upper_Whisker', 'Lower_Whisker',
              'Log_GDP_Per_Capita', 'Social_Support', 'Healthy_Life_Expectancy',
              'Freedom_to_Make_Life_Choices', 'Generosity', 'Perceptions_of_Corruption',
              'Dystopia_Residual']

# %%
df.columns
# Out:
# Index(['Country', 'Ladder_Score', 'Upper_Whisker', 'Lower_Whisker',
#        'Log_GDP_Per_Capita', 'Social_Support', 'Healthy_Life_Expectancy',
#        'Freedom_to_Make_Life_Choices', 'Generosity',
#        'Perceptions_of_Corruption', 'Dystopia_Residual'],
#       dtype='object')

# %%
df_sorted = df.sort_values(by='Ladder_Score', ascending=False)

# Välj de 10 första länderna
top_10_happy_countries = df_sorted.head(10)

# Visa resultatet
print(top_10_happy_countries[['Country', 'Ladder_Score']])
# Out:
#        Country  Ladder_Score
# 0      Finland        7.7407
# 1      Denmark        7.5827
# 2      Iceland        7.5251
# 3       Sweden        7.3441
# 4       Israel        7.3411
# 5  Netherlands        7.3194
# 6       Norway        7.3017
# 7   Luxembourg        7.1219
# 8  Switzerland        7.0602
# 9    Australia        7.0569

# %%
happiest10 = top_10_happy_countries

# %%
fig , ax = plt.subplots(figsize=(14, 8))
plt.bar(happiest10['Country'], happiest10['Ladder_Score'], color='blue')
# Out:
# <BarContainer object of 10 artists>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Sortera efter 'Ladder score' i fallande ordning
df_sorted = df.sort_values(by='Ladder_Score', ascending=False)

# Välj de 10 första länderna
top_10_happy_countries = df_sorted.head(10)

# Skapa barplot
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Country', y='Ladder_Score', data=top_10_happy_countries, palette='pastel')

# Ändra färg på baren vid index 3 (fjärde baren)
bars = ax.patches
bars[3].set_facecolor('Blue')  # Byt ut 'red' mot den färg du vill ha

ax.set_title("Sweden is the 4th happiest country in the world",
             pad=20, fontsize=16, color='black',loc = 'left')
ax.set_xlabel("Countries", fontsize=14, color='black',loc = 'left')
ax.set_ylabel("Happines Score", fontsize=14, color='black')
ax.xaxis.labelpad = 20
ax.yaxis.labelpad = 20

ax.spines[['top','right']].set_visible(False)  # Döljer de övre och högra spines
# Rotera x-axelns etiketter för bättre läsbarhet
plt.xticks(rotation=0, ha='right')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom= False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom= True
)
plt.xticks(ha = 'right')
bars = ax.patches
for i, bar in enumerate(bars):
    if i != 3:  # om det inte är baren du vill highlighta
        bar.set_facecolor('gray'),bar.set_edgecolor('black'),bar.set_linewidth(1.5)
for label in ax.get_xticklabels():
    label.set_horizontalalignment('center')  # eller 'right' / 'center'
    label.set_x(label.get_position()[0] - 10000)
ax.annotate(text ='', xy=(3, 7.5), xytext=(3, 8.2),
            arrowprops=dict(arrowstyle='simple', color='black', lw=1), fontsize=12, color='black')
# Visa plot
plt.tight_layout()

plt.savefig('../plots/happiest_countries.png', dpi=100, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\nirre\AppData\Local\Temp\ipykernel_20864\1808718593.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Country', y='Ladder_Score', data=top_10_happy_countries, palette='pastel')

# %%
df.columns
# Out:
# Index(['Country', 'Ladder_Score', 'Upper_Whisker', 'Lower_Whisker',
#        'Log_GDP_Per_Capita', 'Social_Support', 'Healthy_Life_Expectancy',
#        'Freedom_to_Make_Life_Choices', 'Generosity',
#        'Perceptions_of_Corruption', 'Dystopia_Residual'],
#       dtype='object')

# %%
top_5 = df.nlargest(5, 'Ladder_Score')

# %%
top_5
# Out:
#    Country  Ladder_Score  Upper_Whisker  Lower_Whisker  Log_GDP_Per_Capita  \
# 0  Finland        7.7407       7.814808       7.666591            1.844054
# 1  Denmark        7.5827       7.665297       7.500103            1.907798
# 2  Iceland        7.5251       7.617527       7.432673            1.880718
# 3   Sweden        7.3441       7.421563       7.266637            1.878146
# 4   Israel        7.3411       7.405165       7.277036            1.802934
#
#    Social_Support  Healthy_Life_Expectancy  Freedom_to_Make_Life_Choices  \
# 0        1.572367                 0.694793                      0.859294
# 1        1.520361                 0.698944                      0.822740
# 2        1.616525                 0.718345                      0.818509
# 3        1.500826                 0.723871                      0.838269
# 4        1.512793                 0.739816                      0.641463
#
#    Generosity  Perceptions_of_Corruption  Dystopia_Residual
# ...
